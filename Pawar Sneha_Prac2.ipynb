# %% [markdown]
# #### Practical 2: Implement a basic AI prototype using TensorFlow/PyTorch for an application and Train the model with relevant datasets and evaluate its performance.
# #### Name: Pawar Sneha Sachin
# #### Roll No: 24207148
# #### Class: TY-A  Batch: C

# %% [markdown]
# #### Employee attrition (employees leaving an organization) is a major challenge for companies.The goal of this AI prototype is to predict whether an employee will leave the company or not based on HR data.

# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report

# %%
data = pd.read_csv("WA_Fn-UseC_-HR-Employee-Attrition.csv")
data
# Out:
#       Unnamed: 0  Age Attrition     BusinessTravel  DailyRate  \
# 0              0   41       Yes      Travel_Rarely       1102
# 1              1   49        No  Travel_Frequently        279
# 2              2   37       Yes      Travel_Rarely       1373
# 3              3   33        No  Travel_Frequently       1392
# 4              4   27        No      Travel_Rarely        591
# ...          ...  ...       ...                ...        ...
# 1465        1465   36        No  Travel_Frequently        884
# 1466        1466   39        No      Travel_Rarely        613
# 1467        1467   27        No      Travel_Rarely        155
# 1468        1468   49        No  Travel_Frequently       1023
# 1469        1469   34        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome       Education EducationField  \
# 0                      Sales                 1         College  Life Sciences
# 1     Research & Development                 8  Below College   Life Sciences
# 2     Research & Development                 2         College          Other
# 3     Research & Development                 3          Master  Life Sciences
# 4     Research & Development                 2  Below College         Medical
# ...                      ...               ...             ...            ...
# 1465  Research & Development                23         College        Medical
# 1466  Research & Development                 6  Below College         Medical
# 1467  Research & Development                 4        Bachelor  Life Sciences
# 1468                   Sales                 2        Bachelor        Medical
# 1469  Research & Development                 8        Bachelor        Medical
#
#       EmployeeCount  ...  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                 1  ...                        0                     5
# 1                 1  ...                        1                     7
# 2                 1  ...                        0                     0
# 3                 1  ...                        3                     0
# 4                 1  ...                        2                     2
# ...             ...  ...                      ...                   ...
# 1465              1  ...                        0                     3
# 1466              1  ...                        1                     7
# 1467              1  ...                        0                     3
# 1468              1  ...                        0                     8
# 1469              1  ...                        1                     2
#
#        DailyRateGroups  HourlyRateGroups  MonthlyIncomeGroups  \
# 0     K - 1100 => 1200     I - 90 => 100     E - 5000 => 6000
# 1       B - 200 => 300      F - 60 => 70     E - 5000 => 6000
# 2     M - 1300 => 1400     I - 90 => 100     B - 2000 => 3000
# 3     M - 1300 => 1400      E - 50 => 60     B - 2000 => 3000
# 4       E - 500 => 600      C - 30 => 40     C - 3000 => 4000
# ...                ...               ...                  ...
# 1465    H - 800 => 900      D - 40 => 50     B - 2000 => 3000
# 1466    F - 600 => 700      D - 40 => 50    I - 9000 => 10000
# 1467    A - 100 => 200      H - 80 => 90     F - 6000 => 7000
# 1468  J - 1000 => 1100      F - 60 => 70     E - 5000 => 6000
# 1469    F - 600 => 700      H - 80 => 90     D - 4000 => 5000
#
#        MonthlyRateGroups TotalWorkingYearsGroups  YearsAtCompanyGroups  \
# 0     S - 19000 => 20000       D - 6 => 10 Years     D - 6 => 10 Years
# 1     X - 24000 => 25000       D - 6 => 10 Years     D - 6 => 10 Years
# 2       B - 2000 => 3000       D - 6 => 10 Years       A - 0 => 1 Year
# 3     W - 23000 => 24000       D - 6 => 10 Years     D - 6 => 10 Years
# 4     P - 16000 => 17000       D - 6 => 10 Years      B - 2 => 3 Years
# ...                  ...                     ...                   ...
# 1465  L - 12000 => 13000      F - 16 => 20 Years      C - 4 => 5 Years
# 1466  U - 21000 => 22000       D - 6 => 10 Years     D - 6 => 10 Years
# 1467    E - 5000 => 6000       D - 6 => 10 Years     D - 6 => 10 Years
# 1468  M - 13000 => 14000      F - 16 => 20 Years     D - 6 => 10 Years
# 1469  J - 10000 => 11000       D - 6 => 10 Years      C - 4 => 5 Years
#
#                AgeGroups  YearsBeforeCompanyGroups
# 0     E - 41 => 50 Years          B - 2 => 3 Years
# 1     E - 41 => 50 Years          B - 2 => 3 Years
# 2     D - 31 => 40 Years          B - 2 => 3 Years
# 3     D - 31 => 40 Years          B - 2 => 3 Years
# 4     C - 26 => 30 Years          B - 2 => 3 Years
# ...                  ...                       ...
# 1465  D - 31 => 40 Years          B - 2 => 3 Years
# 1466  D - 31 => 40 Years          B - 2 => 3 Years
# 1467  C - 26 => 30 Years          B - 2 => 3 Years
# 1468  E - 41 => 50 Years          B - 2 => 3 Years
# 1469  D - 31 => 40 Years          B - 2 => 3 Years
#
# [1470 rows x 45 columns]

# %%
# columns do not help in prediction
data.drop(["EmployeeCount",
           "EmployeeNumber",
           "Over18",
           "StandardHours"], axis=1, inplace=True)

# %%
# Convert categorical columns to numeric values
label_encoder = LabelEncoder()

for column in data.select_dtypes(include="object").columns:
    data[column] = label_encoder.fit_transform(data[column])

# %%
# input features
X = data.drop("Attrition", axis=1).values

# target output
y = data["Attrition"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,     # 80% training, 20% testing
    random_state=42
)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = torch.tensor(X_train, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32).view(-1, 1)

X_test = torch.tensor(X_test, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32).view(-1, 1)

# %%
class AttritionModel(nn.Module):
    def __init__(self, input_size):
        super(AttritionModel, self).__init__()

        # First hidden layer
        self.fc1 = nn.Linear(input_size, 64)

        # Second hidden layer
        self.fc2 = nn.Linear(64, 32)

        # Output layer
        self.fc3 = nn.Linear(32, 1)

        # Activation functions
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.sigmoid(self.fc3(x))
        return x

# %%
# Create model object
model = AttritionModel(X_train.shape[1])

# Binary Cross Entropy Loss
criterion = nn.BCELoss()

# Adam optimizer
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
epochs = 20

for epoch in range(epochs):
    # Clear old gradients
    optimizer.zero_grad()

    # Forward pass
    outputs = model(X_train)

    # Calculate loss
    loss = criterion(outputs, y_train)

    # Backpropagation
    loss.backward()

    # Update weights
    optimizer.step()

    if (epoch + 1) % 5 == 0:
        print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [5/20], Loss: 0.6033
# Epoch [10/20], Loss: 0.5649
# Epoch [15/20], Loss: 0.5258
# Epoch [20/20], Loss: 0.4880

# %%
# Disable gradient calculation
with torch.no_grad():
    predictions = model(X_test)
    predicted_classes = (predictions > 0.5).int()

# Accuracy
accuracy = accuracy_score(y_test, predicted_classes)

print("Model Accuracy:", accuracy)
print("\nClassification Report:\n")
print(classification_report(y_test, predicted_classes))
# Out:
# Model Accuracy: 0.8673469387755102
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          0.0       0.87      1.00      0.93       255
#          1.0       0.00      0.00      0.00        39
#
#     accuracy                           0.87       294
#    macro avg       0.43      0.50      0.46       294
# weighted avg       0.75      0.87      0.81       294
# /home/admin1/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/admin1/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/admin1/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# Predict attrition for all employees
with torch.no_grad():
    all_predictions = model(torch.tensor(
        scaler.transform(X), dtype=torch.float32
    ))
# 1 = Leaving, 0 = Not Leaving
all_predictions_class = (all_predictions > 0.5).int().numpy()

# %%
data["Prediction"] = all_predictions_class

data["Prediction"] = data["Prediction"].map({
    1: "Employee Will Leave",
    0: "Employee Will Not Leave"
})

# %%
for index, row in data.iterrows():
    print(f"Employee {index + 1}: {row['Prediction']}")
# Out:
# Employee 1: Employee Will Not Leave
# Employee 2: Employee Will Not Leave
# Employee 3: Employee Will Not Leave
# Employee 4: Employee Will Not Leave
# Employee 5: Employee Will Not Leave
# Employee 6: Employee Will Not Leave
# Employee 7: Employee Will Not Leave
# Employee 8: Employee Will Not Leave
# Employee 9: Employee Will Not Leave
# Employee 10: Employee Will Not Leave
# Employee 11: Employee Will Not Leave
# Employee 12: Employee Will Not Leave
# Employee 13: Employee Will Not Leave
# Employee 14: Employee Will Not Leave
# Employee 15: Employee Will Not Leave
# Employee 16: Employee Will Not Leave
# Employee 17: Employee Will Not Leave
# Employee 18: Employee Will Not Leave
# Employee 19: Employee Will Not Leave
# Employee 20: Employee Will Not Leave
# Employee 21: Employee Will Not Leave
# Employee 22: Employee Will Not Leave
# Employee 23: Employee Will Not Leave
# Employee 24: Employee Will Not Leave
# Employee 25: Employee Will Not Leave
# Employee 26: Employee Will Not Leave
# Employee 27: Employee Will Not Leave
# Employee 28: Employee Will Not Leave
# Employee 29: Employee Will Not Leave
# Employee 30: Employee Will Not Leave
# Employee 31: Employee Will Not Leave
# Employee 32: Employee Will Not Leave
# Employee 33: Employee Will Not Leave
# Employee 34: Employee Will Not Leave
# Employee 35: Employee Will Not Leave
# Employee 36: Employee Will Not Leave
# Employee 37: Employee Will Not Leave
# Employee 38: Employee Will Not Leave
# Employee 39: Employee Will Not Leave
# Employee 40: Employee Will Not Leave
# Employee 41: Employee Will Not Leave
# Employee 42: Employee Will Not Leave
# Employee 43: Employee Will Not Leave
# Employee 44: Employee Will Not Leave
# Employee 45: Employee Will Not Leave
# Employee 46: Employee Will Not Leave
# Employee 47: Employee Will Not Leave
# Employee 48: Employee Will Not Leave
# Employee 49: Employee Will Not Leave
# Employee 50: Employee Will Not Leave
# Employee 51: Employee Will Not Leave
# Employee 52: Employee Will Not Leave
# Employee 53: Employee Will Not Leave
# Employee 54: Employee Will Not Leave
# Employee 55: Employee Will Not Leave
# Employee 56: Employee Will Not Leave
# Employee 57: Employee Will Not Leave
# Employee 58: Employee Will Not Leave
# Employee 59: Employee Will Not Leave
# Employee 60: Employee Will Not Leave
# Employee 61: Employee Will Not Leave
# Employee 62: Employee Will Not Leave
# Employee 63: Employee Will Not Leave
# Employee 64: Employee Will Not Leave
# Employee 65: Employee Will Not Leave
# Employee 66: Employee Will Not Leave
# Employee 67: Employee Will Not Leave
# Employee 68: Employee Will Not Leave
# Employee 69: Employee Will Not Leave
# Employee 70: Employee Will Not Leave
# Employee 71: Employee Will Not Leave
# Employee 72: Employee Will Not Leave
# Employee 73: Employee Will Not Leave
# Employee 74: Employee Will Not Leave
# Employee 75: Employee Will Not Leave
# Employee 76: Employee Will Not Leave
# Employee 77: Employee Will Not Leave
# Employee 78: Employee Will Not Leave
# Employee 79: Employee Will Not Leave
# Employee 80: Employee Will Not Leave
# Employee 81: Employee Will Not Leave
# Employee 82: Employee Will Not Leave
# Employee 83: Employee Will Not Leave
# Employee 84: Employee Will Not Leave
# Employee 85: Employee Will Not Leave
# Employee 86: Employee Will Not Leave
# Employee 87: Employee Will Not Leave
# Employee 88: Employee Will Not Leave
# Employee 89: Employee Will Not Leave
# Employee 90: Employee Will Not Leave
# Employee 91: Employee Will Not Leave
# Employee 92: Employee Will Not Leave
# Employee 93: Employee Will Not Leave
# Employee 94: Employee Will Not Leave
# Employee 95: Employee Will Not Leave
# Employee 96: Employee Will Not Leave
# Employee 97: Employee Will Not Leave
# Employee 98: Employee Will Not Leave
# Employee 99: Employee Will Not Leave
# Employee 100: Employee Will Not Leave
# Employee 101: Employee Will Not Leave
# Employee 102: Employee Will Not Leave
# Employee 103: Employee Will Not Leave
# Employee 104: Employee Will Not Leave
# Employee 105: Employee Will Not Leave
# Employee 106: Employee Will Not Leave
# Employee 107: Employee Will Not Leave
# Employee 108: Employee Will Not Leave
# Employee 109: Employee Will Not Leave
# Employee 110: Employee Will Not Leave
# Employee 111: Employee Will Not Leave
# Employee 112: Employee Will Not Leave
# Employee 113: Employee Will Not Leave
# Employee 114: Employee Will Not Leave
# Employee 115: Employee Will Not Leave
# Employee 116: Employee Will Not Leave
# Employee 117: Employee Will Not Leave
# Employee 118: Employee Will Not Leave
# Employee 119: Employee Will Not Leave
# Employee 120: Employee Will Not Leave
# Employee 121: Employee Will Not Leave
# Employee 122: Employee Will Not Leave
# Employee 123: Employee Will Not Leave
# Employee 124: Employee Will Not Leave
# Employee 125: Employee Will Not Leave
# Employee 126: Employee Will Not Leave
# Employee 127: Employee Will Not Leave
# Employee 128: Employee Will Not Leave
# Employee 129: Employee Will Not Leave
# Employee 130: Employee Will Not Leave
# Employee 131: Employee Will Not Leave
# Employee 132: Employee Will Not Leave
# Employee 133: Employee Will Not Leave
# Employee 134: Employee Will Not Leave
# Employee 135: Employee Will Not Leave
# Employee 136: Employee Will Not Leave
# Employee 137: Employee Will Not Leave
# Employee 138: Employee Will Not Leave
# Employee 139: Employee Will Not Leave
# Employee 140: Employee Will Not Leave
# Employee 141: Employee Will Not Leave
# Employee 142: Employee Will Not Leave
# Employee 143: Employee Will Not Leave
# Employee 144: Employee Will Not Leave
# Employee 145: Employee Will Not Leave
# Employee 146: Employee Will Not Leave
# Employee 147: Employee Will Not Leave
# Employee 148: Employee Will Not Leave
# Employee 149: Employee Will Not Leave
# Employee 150: Employee Will Not Leave
# Employee 151: Employee Will Not Leave
# Employee 152: Employee Will Not Leave
# Employee 153: Employee Will Not Leave
# Employee 154: Employee Will Not Leave
# Employee 155: Employee Will Not Leave
# Employee 156: Employee Will Not Leave
# Employee 157: Employee Will Not Leave
# Employee 158: Employee Will Not Leave
# Employee 159: Employee Will Not Leave
# Employee 160: Employee Will Not Leave
# Employee 161: Employee Will Not Leave
# Employee 162: Employee Will Not Leave
# Employee 163: Employee Will Not Leave
# Employee 164: Employee Will Not Leave
# Employee 165: Employee Will Not Leave
# Employee 166: Employee Will Not Leave
# Employee 167: Employee Will Not Leave
# Employee 168: Employee Will Not Leave
# Employee 169: Employee Will Not Leave
# Employee 170: Employee Will Not Leave
# Employee 171: Employee Will Not Leave
# Employee 172: Employee Will Not Leave
# Employee 173: Employee Will Not Leave
# Employee 174: Employee Will Not Leave
# Employee 175: Employee Will Not Leave
# Employee 176: Employee Will Not Leave
# Employee 177: Employee Will Not Leave
# Employee 178: Employee Will Not Leave
# Employee 179: Employee Will Not Leave
# Employee 180: Employee Will Not Leave
# Employee 181: Employee Will Not Leave
# Employee 182: Employee Will Not Leave
# Employee 183: Employee Will Not Leave
# Employee 184: Employee Will Not Leave
# Employee 185: Employee Will Not Leave
# Employee 186: Employee Will Not Leave
# Employee 187: Employee Will Not Leave
# Employee 188: Employee Will Not Leave
# Employee 189: Employee Will Not Leave
# Employee 190: Employee Will Not Leave
# Employee 191: Employee Will Not Leave
# Employee 192: Employee Will Not Leave
# Employee 193: Employee Will Not Leave
# Employee 194: Employee Will Not Leave
# Employee 195: Employee Will Not Leave
# Employee 196: Employee Will Not Leave
# Employee 197: Employee Will Not Leave
# Employee 198: Employee Will Not Leave
# Employee 199: Employee Will Not Leave
# Employee 200: Employee Will Not Leave
# Employee 201: Employee Will Not Leave
# Employee 202: Employee Will Not Leave
# Employee 203: Employee Will Not Leave
# Employee 204: Employee Will Not Leave
# Employee 205: Employee Will Not Leave
# Employee 206: Employee Will Not Leave
# Employee 207: Employee Will Not Leave
# Employee 208: Employee Will Not Leave
# Employee 209: Employee Will Not Leave
# Employee 210: Employee Will Not Leave
# Employee 211: Employee Will Not Leave
# Employee 212: Employee Will Not Leave
# Employee 213: Employee Will Not Leave
# Employee 214: Employee Will Not Leave
# Employee 215: Employee Will Not Leave
# Employee 216: Employee Will Not Leave
# Employee 217: Employee Will Not Leave
# Employee 218: Employee Will Not Leave
# Employee 219: Employee Will Not Leave
# Employee 220: Employee Will Not Leave
# Employee 221: Employee Will Not Leave
# Employee 222: Employee Will Not Leave
# Employee 223: Employee Will Not Leave
# Employee 224: Employee Will Not Leave
# Employee 225: Employee Will Not Leave
# Employee 226: Employee Will Not Leave
# Employee 227: Employee Will Not Leave
# Employee 228: Employee Will Not Leave
# Employee 229: Employee Will Not Leave
# Employee 230: Employee Will Not Leave
# Employee 231: Employee Will Not Leave
# Employee 232: Employee Will Not Leave
# Employee 233: Employee Will Not Leave
# Employee 234: Employee Will Not Leave
# Employee 235: Employee Will Not Leave
# Employee 236: Employee Will Not Leave
# Employee 237: Employee Will Not Leave
# Employee 238: Employee Will Not Leave
# Employee 239: Employee Will Not Leave
# Employee 240: Employee Will Not Leave
# Employee 241: Employee Will Not Leave
# Employee 242: Employee Will Not Leave
# Employee 243: Employee Will Not Leave
# Employee 244: Employee Will Not Leave
# Employee 245: Employee Will Not Leave
# Employee 246: Employee Will Not Leave
# Employee 247: Employee Will Not Leave
# Employee 248: Employee Will Not Leave
# Employee 249: Employee Will Not Leave
# Employee 250: Employee Will Not Leave
# Employee 251: Employee Will Not Leave
# Employee 252: Employee Will Not Leave
# Employee 253: Employee Will Not Leave
# Employee 254: Employee Will Not Leave
# Employee 255: Employee Will Not Leave
# Employee 256: Employee Will Not Leave
# Employee 257: Employee Will Not Leave
# Employee 258: Employee Will Not Leave
# Employee 259: Employee Will Not Leave
# Employee 260: Employee Will Not Leave
# Employee 261: Employee Will Not Leave
# Employee 262: Employee Will Not Leave
# Employee 263: Employee Will Not Leave
# Employee 264: Employee Will Not Leave
# Employee 265: Employee Will Not Leave
# Employee 266: Employee Will Not Leave
# Employee 267: Employee Will Not Leave
# Employee 268: Employee Will Not Leave
# Employee 269: Employee Will Not Leave
# Employee 270: Employee Will Not Leave
# Employee 271: Employee Will Not Leave
# Employee 272: Employee Will Not Leave
# Employee 273: Employee Will Not Leave
# Employee 274: Employee Will Not Leave
# Employee 275: Employee Will Not Leave
# Employee 276: Employee Will Not Leave
# Employee 277: Employee Will Not Leave
# Employee 278: Employee Will Not Leave
# Employee 279: Employee Will Not Leave
# Employee 280: Employee Will Not Leave
# Employee 281: Employee Will Not Leave
# Employee 282: Employee Will Not Leave
# Employee 283: Employee Will Not Leave
# Employee 284: Employee Will Not Leave
# Employee 285: Employee Will Not Leave
# Employee 286: Employee Will Not Leave
# Employee 287: Employee Will Not Leave
# Employee 288: Employee Will Not Leave
# Employee 289: Employee Will Not Leave
# Employee 290: Employee Will Not Leave
# Employee 291: Employee Will Not Leave
# Employee 292: Employee Will Not Leave
# Employee 293: Employee Will Not Leave
# Employee 294: Employee Will Not Leave
# Employee 295: Employee Will Not Leave
# Employee 296: Employee Will Not Leave
# Employee 297: Employee Will Not Leave
# Employee 298: Employee Will Not Leave
# Employee 299: Employee Will Not Leave
# Employee 300: Employee Will Not Leave
# Employee 301: Employee Will Not Leave
# Employee 302: Employee Will Not Leave
# Employee 303: Employee Will Not Leave
# Employee 304: Employee Will Not Leave
# Employee 305: Employee Will Not Leave
# Employee 306: Employee Will Not Leave
# Employee 307: Employee Will Not Leave
# Employee 308: Employee Will Not Leave
# Employee 309: Employee Will Not Leave
# Employee 310: Employee Will Not Leave
# Employee 311: Employee Will Not Leave
# Employee 312: Employee Will Not Leave
# Employee 313: Employee Will Not Leave
# Employee 314: Employee Will Not Leave
# Employee 315: Employee Will Not Leave
# Employee 316: Employee Will Not Leave
# Employee 317: Employee Will Not Leave
# Employee 318: Employee Will Not Leave
# Employee 319: Employee Will Not Leave
# Employee 320: Employee Will Not Leave
# Employee 321: Employee Will Not Leave
# Employee 322: Employee Will Not Leave
# Employee 323: Employee Will Not Leave
# Employee 324: Employee Will Not Leave
# Employee 325: Employee Will Not Leave
# Employee 326: Employee Will Not Leave
# Employee 327: Employee Will Not Leave
# Employee 328: Employee Will Not Leave
# Employee 329: Employee Will Not Leave
# Employee 330: Employee Will Not Leave
# Employee 331: Employee Will Not Leave
# Employee 332: Employee Will Not Leave
# Employee 333: Employee Will Not Leave
# Employee 334: Employee Will Not Leave
# Employee 335: Employee Will Not Leave
# Employee 336: Employee Will Not Leave
# Employee 337: Employee Will Not Leave
# Employee 338: Employee Will Not Leave
# Employee 339: Employee Will Not Leave
# Employee 340: Employee Will Not Leave
# Employee 341: Employee Will Not Leave
# Employee 342: Employee Will Not Leave
# Employee 343: Employee Will Not Leave
# Employee 344: Employee Will Not Leave
# Employee 345: Employee Will Not Leave
# Employee 346: Employee Will Not Leave
# Employee 347: Employee Will Not Leave
# Employee 348: Employee Will Not Leave
# Employee 349: Employee Will Not Leave
# Employee 350: Employee Will Not Leave
# Employee 351: Employee Will Not Leave
# Employee 352: Employee Will Not Leave
# Employee 353: Employee Will Not Leave
# Employee 354: Employee Will Not Leave
# Employee 355: Employee Will Not Leave
# Employee 356: Employee Will Not Leave
# Employee 357: Employee Will Not Leave
# Employee 358: Employee Will Not Leave
# Employee 359: Employee Will Not Leave
# Employee 360: Employee Will Not Leave
# Employee 361: Employee Will Not Leave
# Employee 362: Employee Will Not Leave
# Employee 363: Employee Will Not Leave
# Employee 364: Employee Will Not Leave
# Employee 365: Employee Will Not Leave
# Employee 366: Employee Will Not Leave
# Employee 367: Employee Will Not Leave
# Employee 368: Employee Will Not Leave
# Employee 369: Employee Will Not Leave
# Employee 370: Employee Will Not Leave
# Employee 371: Employee Will Not Leave
# Employee 372: Employee Will Not Leave
# Employee 373: Employee Will Not Leave
# Employee 374: Employee Will Not Leave
# Employee 375: Employee Will Not Leave
# Employee 376: Employee Will Not Leave
# Employee 377: Employee Will Not Leave
# Employee 378: Employee Will Not Leave
# Employee 379: Employee Will Not Leave
# Employee 380: Employee Will Not Leave
# Employee 381: Employee Will Not Leave
# Employee 382: Employee Will Not Leave
# Employee 383: Employee Will Not Leave
# Employee 384: Employee Will Not Leave
# Employee 385: Employee Will Not Leave
# Employee 386: Employee Will Not Leave
# Employee 387: Employee Will Not Leave
# Employee 388: Employee Will Not Leave
# Employee 389: Employee Will Not Leave
# Employee 390: Employee Will Not Leave
# Employee 391: Employee Will Not Leave
# Employee 392: Employee Will Not Leave
# Employee 393: Employee Will Not Leave
# Employee 394: Employee Will Not Leave
# Employee 395: Employee Will Not Leave
# Employee 396: Employee Will Not Leave
# Employee 397: Employee Will Not Leave
# Employee 398: Employee Will Not Leave
# Employee 399: Employee Will Not Leave
# Employee 400: Employee Will Not Leave
# Employee 401: Employee Will Not Leave
# Employee 402: Employee Will Not Leave
# Employee 403: Employee Will Not Leave
# Employee 404: Employee Will Not Leave
# Employee 405: Employee Will Not Leave
# Employee 406: Employee Will Not Leave
# Employee 407: Employee Will Not Leave
# Employee 408: Employee Will Not Leave
# Employee 409: Employee Will Not Leave
# Employee 410: Employee Will Not Leave
# Employee 411: Employee Will Not Leave
# Employee 412: Employee Will Not Leave
# Employee 413: Employee Will Not Leave
# Employee 414: Employee Will Not Leave
# Employee 415: Employee Will Not Leave
# Employee 416: Employee Will Not Leave
# Employee 417: Employee Will Not Leave
# Employee 418: Employee Will Not Leave
# Employee 419: Employee Will Not Leave
# Employee 420: Employee Will Not Leave
# Employee 421: Employee Will Not Leave
# Employee 422: Employee Will Not Leave
# Employee 423: Employee Will Not Leave
# Employee 424: Employee Will Not Leave
# Employee 425: Employee Will Not Leave
# Employee 426: Employee Will Not Leave
# Employee 427: Employee Will Not Leave
# Employee 428: Employee Will Not Leave
# Employee 429: Employee Will Not Leave
# Employee 430: Employee Will Not Leave
# Employee 431: Employee Will Not Leave
# Employee 432: Employee Will Not Leave
# Employee 433: Employee Will Not Leave
# Employee 434: Employee Will Not Leave
# Employee 435: Employee Will Not Leave
# Employee 436: Employee Will Not Leave
# Employee 437: Employee Will Not Leave
# Employee 438: Employee Will Not Leave
# Employee 439: Employee Will Not Leave
# Employee 440: Employee Will Not Leave
# Employee 441: Employee Will Not Leave
# Employee 442: Employee Will Not Leave
# Employee 443: Employee Will Not Leave
# Employee 444: Employee Will Not Leave
# Employee 445: Employee Will Not Leave
# Employee 446: Employee Will Not Leave
# Employee 447: Employee Will Not Leave
# Employee 448: Employee Will Not Leave
# Employee 449: Employee Will Not Leave
# Employee 450: Employee Will Not Leave
# Employee 451: Employee Will Not Leave
# Employee 452: Employee Will Not Leave
# Employee 453: Employee Will Not Leave
# Employee 454: Employee Will Not Leave
# Employee 455: Employee Will Not Leave
# Employee 456: Employee Will Not Leave
# Employee 457: Employee Will Not Leave
# Employee 458: Employee Will Not Leave
# Employee 459: Employee Will Not Leave
# Employee 460: Employee Will Not Leave
# Employee 461: Employee Will Not Leave
# Employee 462: Employee Will Not Leave
# Employee 463: Employee Will Not Leave
# Employee 464: Employee Will Not Leave
# Employee 465: Employee Will Not Leave
# Employee 466: Employee Will Not Leave
# Employee 467: Employee Will Not Leave
# Employee 468: Employee Will Not Leave
# Employee 469: Employee Will Not Leave
# Employee 470: Employee Will Not Leave
# Employee 471: Employee Will Not Leave
# Employee 472: Employee Will Not Leave
# Employee 473: Employee Will Not Leave
# Employee 474: Employee Will Not Leave
# Employee 475: Employee Will Not Leave
# Employee 476: Employee Will Not Leave
# Employee 477: Employee Will Not Leave
# Employee 478: Employee Will Not Leave
# Employee 479: Employee Will Not Leave
# Employee 480: Employee Will Not Leave
# Employee 481: Employee Will Not Leave
# Employee 482: Employee Will Not Leave
# Employee 483: Employee Will Not Leave
# Employee 484: Employee Will Not Leave
# Employee 485: Employee Will Not Leave
# Employee 486: Employee Will Not Leave
# Employee 487: Employee Will Not Leave
# Employee 488: Employee Will Not Leave
# Employee 489: Employee Will Not Leave
# Employee 490: Employee Will Not Leave
# Employee 491: Employee Will Not Leave
# Employee 492: Employee Will Not Leave
# Employee 493: Employee Will Not Leave
# Employee 494: Employee Will Not Leave
# Employee 495: Employee Will Not Leave
# Employee 496: Employee Will Not Leave
# Employee 497: Employee Will Not Leave
# Employee 498: Employee Will Not Leave
# Employee 499: Employee Will Not Leave
# Employee 500: Employee Will Not Leave
# Employee 501: Employee Will Not Leave
# Employee 502: Employee Will Not Leave
# Employee 503: Employee Will Not Leave
# Employee 504: Employee Will Not Leave
# Employee 505: Employee Will Not Leave
# Employee 506: Employee Will Not Leave
# Employee 507: Employee Will Not Leave
# Employee 508: Employee Will Not Leave
# Employee 509: Employee Will Not Leave
# Employee 510: Employee Will Not Leave
# Employee 511: Employee Will Not Leave
# Employee 512: Employee Will Not Leave
# Employee 513: Employee Will Not Leave
# Employee 514: Employee Will Not Leave
# Employee 515: Employee Will Not Leave
# Employee 516: Employee Will Not Leave
# Employee 517: Employee Will Not Leave
# Employee 518: Employee Will Not Leave
# Employee 519: Employee Will Not Leave
# Employee 520: Employee Will Not Leave
# Employee 521: Employee Will Not Leave
# Employee 522: Employee Will Not Leave
# Employee 523: Employee Will Not Leave
# Employee 524: Employee Will Not Leave
# Employee 525: Employee Will Not Leave
# Employee 526: Employee Will Not Leave
# Employee 527: Employee Will Not Leave
# Employee 528: Employee Will Not Leave
# Employee 529: Employee Will Not Leave
# Employee 530: Employee Will Not Leave
# Employee 531: Employee Will Not Leave
# Employee 532: Employee Will Not Leave
# Employee 533: Employee Will Not Leave
# Employee 534: Employee Will Not Leave
# Employee 535: Employee Will Not Leave
# Employee 536: Employee Will Not Leave
# Employee 537: Employee Will Not Leave
# Employee 538: Employee Will Not Leave
# Employee 539: Employee Will Not Leave
# Employee 540: Employee Will Not Leave
# Employee 541: Employee Will Not Leave
# Employee 542: Employee Will Not Leave
# Employee 543: Employee Will Not Leave
# Employee 544: Employee Will Not Leave
# Employee 545: Employee Will Not Leave
# Employee 546: Employee Will Not Leave
# Employee 547: Employee Will Not Leave
# Employee 548: Employee Will Not Leave
# Employee 549: Employee Will Not Leave
# Employee 550: Employee Will Not Leave
# Employee 551: Employee Will Not Leave
# Employee 552: Employee Will Not Leave
# Employee 553: Employee Will Not Leave
# Employee 554: Employee Will Not Leave
# Employee 555: Employee Will Not Leave
# Employee 556: Employee Will Not Leave
# Employee 557: Employee Will Not Leave
# Employee 558: Employee Will Not Leave
# Employee 559: Employee Will Not Leave
# Employee 560: Employee Will Not Leave
# Employee 561: Employee Will Not Leave
# Employee 562: Employee Will Not Leave
# Employee 563: Employee Will Not Leave
# Employee 564: Employee Will Not Leave
# Employee 565: Employee Will Not Leave
# Employee 566: Employee Will Not Leave
# Employee 567: Employee Will Not Leave
# Employee 568: Employee Will Not Leave
# Employee 569: Employee Will Not Leave
# Employee 570: Employee Will Not Leave
# Employee 571: Employee Will Not Leave
# Employee 572: Employee Will Not Leave
# Employee 573: Employee Will Not Leave
# Employee 574: Employee Will Not Leave
# Employee 575: Employee Will Not Leave
# Employee 576: Employee Will Not Leave
# Employee 577: Employee Will Not Leave
# Employee 578: Employee Will Not Leave
# Employee 579: Employee Will Not Leave
# Employee 580: Employee Will Not Leave
# Employee 581: Employee Will Not Leave
# Employee 582: Employee Will Not Leave
# Employee 583: Employee Will Not Leave
# Employee 584: Employee Will Not Leave
# Employee 585: Employee Will Not Leave
# Employee 586: Employee Will Not Leave
# Employee 587: Employee Will Not Leave
# Employee 588: Employee Will Not Leave
# Employee 589: Employee Will Not Leave
# Employee 590: Employee Will Not Leave
# Employee 591: Employee Will Not Leave
# Employee 592: Employee Will Not Leave
# Employee 593: Employee Will Not Leave
# Employee 594: Employee Will Not Leave
# Employee 595: Employee Will Not Leave
# Employee 596: Employee Will Not Leave
# Employee 597: Employee Will Not Leave
# Employee 598: Employee Will Not Leave
# Employee 599: Employee Will Not Leave
# Employee 600: Employee Will Not Leave
# Employee 601: Employee Will Not Leave
# Employee 602: Employee Will Not Leave
# Employee 603: Employee Will Not Leave
# Employee 604: Employee Will Not Leave
# Employee 605: Employee Will Not Leave
# Employee 606: Employee Will Not Leave
# Employee 607: Employee Will Not Leave
# Employee 608: Employee Will Not Leave
# Employee 609: Employee Will Not Leave
# Employee 610: Employee Will Not Leave
# Employee 611: Employee Will Not Leave
# Employee 612: Employee Will Not Leave
# Employee 613: Employee Will Not Leave
# Employee 614: Employee Will Not Leave
# Employee 615: Employee Will Not Leave
# Employee 616: Employee Will Not Leave
# Employee 617: Employee Will Not Leave
# Employee 618: Employee Will Not Leave
# Employee 619: Employee Will Not Leave
# Employee 620: Employee Will Not Leave
# Employee 621: Employee Will Not Leave
# Employee 622: Employee Will Not Leave
# Employee 623: Employee Will Not Leave
# Employee 624: Employee Will Not Leave
# Employee 625: Employee Will Not Leave
# Employee 626: Employee Will Not Leave
# Employee 627: Employee Will Not Leave
# Employee 628: Employee Will Not Leave
# Employee 629: Employee Will Not Leave
# Employee 630: Employee Will Not Leave
# Employee 631: Employee Will Not Leave
# Employee 632: Employee Will Not Leave
# Employee 633: Employee Will Not Leave
# Employee 634: Employee Will Not Leave
# Employee 635: Employee Will Not Leave
# Employee 636: Employee Will Not Leave
# Employee 637: Employee Will Not Leave
# Employee 638: Employee Will Not Leave
# Employee 639: Employee Will Not Leave
# Employee 640: Employee Will Not Leave
# Employee 641: Employee Will Not Leave
# Employee 642: Employee Will Not Leave
# Employee 643: Employee Will Not Leave
# Employee 644: Employee Will Not Leave
# Employee 645: Employee Will Not Leave
# Employee 646: Employee Will Not Leave
# Employee 647: Employee Will Not Leave
# Employee 648: Employee Will Not Leave
# Employee 649: Employee Will Not Leave
# Employee 650: Employee Will Not Leave
# Employee 651: Employee Will Not Leave
# Employee 652: Employee Will Not Leave
# Employee 653: Employee Will Not Leave
# Employee 654: Employee Will Not Leave
# Employee 655: Employee Will Not Leave
# Employee 656: Employee Will Not Leave
# Employee 657: Employee Will Not Leave
# Employee 658: Employee Will Not Leave
# Employee 659: Employee Will Not Leave
# Employee 660: Employee Will Not Leave
# Employee 661: Employee Will Not Leave
# Employee 662: Employee Will Not Leave
# Employee 663: Employee Will Not Leave
# Employee 664: Employee Will Not Leave
# Employee 665: Employee Will Not Leave
# Employee 666: Employee Will Not Leave
# Employee 667: Employee Will Not Leave
# Employee 668: Employee Will Not Leave
# Employee 669: Employee Will Not Leave
# Employee 670: Employee Will Not Leave
# Employee 671: Employee Will Not Leave
# Employee 672: Employee Will Not Leave
# Employee 673: Employee Will Not Leave
# Employee 674: Employee Will Not Leave
# Employee 675: Employee Will Not Leave
# Employee 676: Employee Will Not Leave
# Employee 677: Employee Will Not Leave
# Employee 678: Employee Will Not Leave
# Employee 679: Employee Will Not Leave
# Employee 680: Employee Will Not Leave
# Employee 681: Employee Will Not Leave
# Employee 682: Employee Will Not Leave
# Employee 683: Employee Will Not Leave
# Employee 684: Employee Will Not Leave
# Employee 685: Employee Will Not Leave
# Employee 686: Employee Will Not Leave
# Employee 687: Employee Will Not Leave
# Employee 688: Employee Will Not Leave
# Employee 689: Employee Will Not Leave
# Employee 690: Employee Will Not Leave
# Employee 691: Employee Will Not Leave
# Employee 692: Employee Will Not Leave
# Employee 693: Employee Will Not Leave
# Employee 694: Employee Will Not Leave
# Employee 695: Employee Will Not Leave
# Employee 696: Employee Will Not Leave
# Employee 697: Employee Will Not Leave
# Employee 698: Employee Will Not Leave
# Employee 699: Employee Will Not Leave
# Employee 700: Employee Will Not Leave
# Employee 701: Employee Will Not Leave
# Employee 702: Employee Will Not Leave
# Employee 703: Employee Will Not Leave
# Employee 704: Employee Will Not Leave
# Employee 705: Employee Will Not Leave
# Employee 706: Employee Will Not Leave
# Employee 707: Employee Will Not Leave
# Employee 708: Employee Will Not Leave
# Employee 709: Employee Will Not Leave
# Employee 710: Employee Will Not Leave
# Employee 711: Employee Will Not Leave
# Employee 712: Employee Will Not Leave
# Employee 713: Employee Will Not Leave
# Employee 714: Employee Will Not Leave
# Employee 715: Employee Will Not Leave
# Employee 716: Employee Will Not Leave
# Employee 717: Employee Will Not Leave
# Employee 718: Employee Will Not Leave
# Employee 719: Employee Will Not Leave
# Employee 720: Employee Will Not Leave
# Employee 721: Employee Will Not Leave
# Employee 722: Employee Will Not Leave
# Employee 723: Employee Will Not Leave
# Employee 724: Employee Will Not Leave
# Employee 725: Employee Will Not Leave
# Employee 726: Employee Will Not Leave
# Employee 727: Employee Will Not Leave
# Employee 728: Employee Will Not Leave
# Employee 729: Employee Will Not Leave
# Employee 730: Employee Will Not Leave
# Employee 731: Employee Will Not Leave
# Employee 732: Employee Will Not Leave
# Employee 733: Employee Will Not Leave
# Employee 734: Employee Will Not Leave
# Employee 735: Employee Will Not Leave
# Employee 736: Employee Will Not Leave
# Employee 737: Employee Will Not Leave
# Employee 738: Employee Will Not Leave
# Employee 739: Employee Will Not Leave
# Employee 740: Employee Will Not Leave
# Employee 741: Employee Will Not Leave
# Employee 742: Employee Will Not Leave
# Employee 743: Employee Will Not Leave
# Employee 744: Employee Will Not Leave
# Employee 745: Employee Will Not Leave
# Employee 746: Employee Will Not Leave
# Employee 747: Employee Will Not Leave
# Employee 748: Employee Will Not Leave
# Employee 749: Employee Will Not Leave
# Employee 750: Employee Will Not Leave
# Employee 751: Employee Will Not Leave
# Employee 752: Employee Will Not Leave
# Employee 753: Employee Will Not Leave
# Employee 754: Employee Will Not Leave
# Employee 755: Employee Will Not Leave
# Employee 756: Employee Will Not Leave
# Employee 757: Employee Will Not Leave
# Employee 758: Employee Will Not Leave
# Employee 759: Employee Will Not Leave
# Employee 760: Employee Will Not Leave
# Employee 761: Employee Will Not Leave
# Employee 762: Employee Will Not Leave
# Employee 763: Employee Will Not Leave
# Employee 764: Employee Will Not Leave
# Employee 765: Employee Will Not Leave
# Employee 766: Employee Will Not Leave
# Employee 767: Employee Will Not Leave
# Employee 768: Employee Will Not Leave
# Employee 769: Employee Will Not Leave
# Employee 770: Employee Will Not Leave
# Employee 771: Employee Will Not Leave
# Employee 772: Employee Will Not Leave
# Employee 773: Employee Will Not Leave
# Employee 774: Employee Will Not Leave
# Employee 775: Employee Will Not Leave
# Employee 776: Employee Will Not Leave
# Employee 777: Employee Will Not Leave
# Employee 778: Employee Will Not Leave
# Employee 779: Employee Will Not Leave
# Employee 780: Employee Will Not Leave
# Employee 781: Employee Will Not Leave
# Employee 782: Employee Will Not Leave
# Employee 783: Employee Will Not Leave
# Employee 784: Employee Will Not Leave
# Employee 785: Employee Will Not Leave
# Employee 786: Employee Will Not Leave
# Employee 787: Employee Will Not Leave
# Employee 788: Employee Will Not Leave
# Employee 789: Employee Will Not Leave
# Employee 790: Employee Will Not Leave
# Employee 791: Employee Will Not Leave
# Employee 792: Employee Will Not Leave
# Employee 793: Employee Will Not Leave
# Employee 794: Employee Will Not Leave
# Employee 795: Employee Will Not Leave
# Employee 796: Employee Will Not Leave
# Employee 797: Employee Will Not Leave
# Employee 798: Employee Will Not Leave
# Employee 799: Employee Will Not Leave
# Employee 800: Employee Will Not Leave
# Employee 801: Employee Will Not Leave
# Employee 802: Employee Will Not Leave
# Employee 803: Employee Will Not Leave
# Employee 804: Employee Will Not Leave
# Employee 805: Employee Will Not Leave
# Employee 806: Employee Will Not Leave
# Employee 807: Employee Will Not Leave
# Employee 808: Employee Will Not Leave
# Employee 809: Employee Will Not Leave
# Employee 810: Employee Will Not Leave
# Employee 811: Employee Will Not Leave
# Employee 812: Employee Will Not Leave
# Employee 813: Employee Will Not Leave
# Employee 814: Employee Will Not Leave
# Employee 815: Employee Will Not Leave
# Employee 816: Employee Will Not Leave
# Employee 817: Employee Will Not Leave
# Employee 818: Employee Will Not Leave
# Employee 819: Employee Will Not Leave
# Employee 820: Employee Will Not Leave
# Employee 821: Employee Will Not Leave
# Employee 822: Employee Will Not Leave
# Employee 823: Employee Will Not Leave
# Employee 824: Employee Will Not Leave
# Employee 825: Employee Will Not Leave
# Employee 826: Employee Will Not Leave
# Employee 827: Employee Will Not Leave
# Employee 828: Employee Will Not Leave
# Employee 829: Employee Will Not Leave
# Employee 830: Employee Will Not Leave
# Employee 831: Employee Will Not Leave
# Employee 832: Employee Will Not Leave
# Employee 833: Employee Will Not Leave
# Employee 834: Employee Will Not Leave
# Employee 835: Employee Will Not Leave
# Employee 836: Employee Will Not Leave
# Employee 837: Employee Will Not Leave
# Employee 838: Employee Will Not Leave
# Employee 839: Employee Will Not Leave
# Employee 840: Employee Will Not Leave
# Employee 841: Employee Will Not Leave
# Employee 842: Employee Will Not Leave
# Employee 843: Employee Will Not Leave
# Employee 844: Employee Will Not Leave
# Employee 845: Employee Will Not Leave
# Employee 846: Employee Will Not Leave
# Employee 847: Employee Will Not Leave
# Employee 848: Employee Will Not Leave
# Employee 849: Employee Will Not Leave
# Employee 850: Employee Will Not Leave
# Employee 851: Employee Will Not Leave
# Employee 852: Employee Will Not Leave
# Employee 853: Employee Will Not Leave
# Employee 854: Employee Will Not Leave
# Employee 855: Employee Will Not Leave
# Employee 856: Employee Will Not Leave
# Employee 857: Employee Will Not Leave
# Employee 858: Employee Will Not Leave
# Employee 859: Employee Will Not Leave
# Employee 860: Employee Will Not Leave
# Employee 861: Employee Will Not Leave
# Employee 862: Employee Will Not Leave
# Employee 863: Employee Will Not Leave
# Employee 864: Employee Will Not Leave
# Employee 865: Employee Will Not Leave
# Employee 866: Employee Will Not Leave
# Employee 867: Employee Will Not Leave
# Employee 868: Employee Will Not Leave
# Employee 869: Employee Will Not Leave
# Employee 870: Employee Will Not Leave
# Employee 871: Employee Will Not Leave
# Employee 872: Employee Will Not Leave
# Employee 873: Employee Will Not Leave
# Employee 874: Employee Will Not Leave
# Employee 875: Employee Will Not Leave
# Employee 876: Employee Will Not Leave
# Employee 877: Employee Will Not Leave
# Employee 878: Employee Will Not Leave
# Employee 879: Employee Will Not Leave
# Employee 880: Employee Will Not Leave
# Employee 881: Employee Will Not Leave
# Employee 882: Employee Will Not Leave
# Employee 883: Employee Will Not Leave
# Employee 884: Employee Will Not Leave
# Employee 885: Employee Will Not Leave
# Employee 886: Employee Will Not Leave
# Employee 887: Employee Will Not Leave
# Employee 888: Employee Will Not Leave
# Employee 889: Employee Will Not Leave
# Employee 890: Employee Will Not Leave
# Employee 891: Employee Will Not Leave
# Employee 892: Employee Will Not Leave
# Employee 893: Employee Will Not Leave
# Employee 894: Employee Will Not Leave
# Employee 895: Employee Will Not Leave
# Employee 896: Employee Will Not Leave
# Employee 897: Employee Will Not Leave
# Employee 898: Employee Will Not Leave
# Employee 899: Employee Will Not Leave
# Employee 900: Employee Will Not Leave
# Employee 901: Employee Will Not Leave
# Employee 902: Employee Will Not Leave
# Employee 903: Employee Will Not Leave
# Employee 904: Employee Will Not Leave
# Employee 905: Employee Will Not Leave
# Employee 906: Employee Will Not Leave
# Employee 907: Employee Will Not Leave
# Employee 908: Employee Will Not Leave
# Employee 909: Employee Will Not Leave
# Employee 910: Employee Will Not Leave
# Employee 911: Employee Will Not Leave
# Employee 912: Employee Will Not Leave
# Employee 913: Employee Will Not Leave
# Employee 914: Employee Will Not Leave
# Employee 915: Employee Will Not Leave
# Employee 916: Employee Will Not Leave
# Employee 917: Employee Will Not Leave
# Employee 918: Employee Will Not Leave
# Employee 919: Employee Will Not Leave
# Employee 920: Employee Will Not Leave
# Employee 921: Employee Will Not Leave
# Employee 922: Employee Will Not Leave
# Employee 923: Employee Will Not Leave
# Employee 924: Employee Will Not Leave
# Employee 925: Employee Will Not Leave
# Employee 926: Employee Will Not Leave
# Employee 927: Employee Will Not Leave
# Employee 928: Employee Will Not Leave
# Employee 929: Employee Will Not Leave
# Employee 930: Employee Will Not Leave
# Employee 931: Employee Will Not Leave
# Employee 932: Employee Will Not Leave
# Employee 933: Employee Will Not Leave
# Employee 934: Employee Will Not Leave
# Employee 935: Employee Will Not Leave
# Employee 936: Employee Will Not Leave
# Employee 937: Employee Will Not Leave
# Employee 938: Employee Will Not Leave
# Employee 939: Employee Will Not Leave
# Employee 940: Employee Will Not Leave
# Employee 941: Employee Will Not Leave
# Employee 942: Employee Will Not Leave
# Employee 943: Employee Will Not Leave
# Employee 944: Employee Will Not Leave
# Employee 945: Employee Will Not Leave
# Employee 946: Employee Will Not Leave
# Employee 947: Employee Will Not Leave
# Employee 948: Employee Will Not Leave
# Employee 949: Employee Will Not Leave
# Employee 950: Employee Will Not Leave
# Employee 951: Employee Will Not Leave
# Employee 952: Employee Will Not Leave
# Employee 953: Employee Will Not Leave
# Employee 954: Employee Will Not Leave
# Employee 955: Employee Will Not Leave
# Employee 956: Employee Will Not Leave
# Employee 957: Employee Will Not Leave
# Employee 958: Employee Will Not Leave
# Employee 959: Employee Will Not Leave
# Employee 960: Employee Will Not Leave
# Employee 961: Employee Will Not Leave
# Employee 962: Employee Will Not Leave
# Employee 963: Employee Will Not Leave
# Employee 964: Employee Will Not Leave
# Employee 965: Employee Will Not Leave
# Employee 966: Employee Will Not Leave
# Employee 967: Employee Will Not Leave
# Employee 968: Employee Will Not Leave
# Employee 969: Employee Will Not Leave
# Employee 970: Employee Will Not Leave
# Employee 971: Employee Will Not Leave
# Employee 972: Employee Will Not Leave
# Employee 973: Employee Will Not Leave
# Employee 974: Employee Will Not Leave
# Employee 975: Employee Will Not Leave
# Employee 976: Employee Will Not Leave
# Employee 977: Employee Will Not Leave
# Employee 978: Employee Will Not Leave
# Employee 979: Employee Will Not Leave
# Employee 980: Employee Will Not Leave
# Employee 981: Employee Will Not Leave
# Employee 982: Employee Will Not Leave
# Employee 983: Employee Will Not Leave
# Employee 984: Employee Will Not Leave
# Employee 985: Employee Will Not Leave
# Employee 986: Employee Will Not Leave
# Employee 987: Employee Will Not Leave
# Employee 988: Employee Will Not Leave
# Employee 989: Employee Will Not Leave
# Employee 990: Employee Will Not Leave
# Employee 991: Employee Will Not Leave
# Employee 992: Employee Will Not Leave
# Employee 993: Employee Will Not Leave
# Employee 994: Employee Will Not Leave
# Employee 995: Employee Will Not Leave
# Employee 996: Employee Will Not Leave
# Employee 997: Employee Will Not Leave
# Employee 998: Employee Will Not Leave
# Employee 999: Employee Will Not Leave
# Employee 1000: Employee Will Not Leave
# Employee 1001: Employee Will Not Leave
# Employee 1002: Employee Will Not Leave
# Employee 1003: Employee Will Not Leave
# Employee 1004: Employee Will Not Leave
# Employee 1005: Employee Will Not Leave
# Employee 1006: Employee Will Not Leave
# Employee 1007: Employee Will Not Leave
# Employee 1008: Employee Will Not Leave
# Employee 1009: Employee Will Not Leave
# Employee 1010: Employee Will Not Leave
# Employee 1011: Employee Will Not Leave
# Employee 1012: Employee Will Not Leave
# Employee 1013: Employee Will Not Leave
# Employee 1014: Employee Will Not Leave
# Employee 1015: Employee Will Not Leave
# Employee 1016: Employee Will Not Leave
# Employee 1017: Employee Will Not Leave
# Employee 1018: Employee Will Not Leave
# Employee 1019: Employee Will Not Leave
# Employee 1020: Employee Will Not Leave
# Employee 1021: Employee Will Not Leave
# Employee 1022: Employee Will Not Leave
# Employee 1023: Employee Will Not Leave
# Employee 1024: Employee Will Not Leave
# Employee 1025: Employee Will Not Leave
# Employee 1026: Employee Will Not Leave
# Employee 1027: Employee Will Not Leave
# Employee 1028: Employee Will Not Leave
# Employee 1029: Employee Will Not Leave
# Employee 1030: Employee Will Not Leave
# Employee 1031: Employee Will Not Leave
# Employee 1032: Employee Will Not Leave
# Employee 1033: Employee Will Not Leave
# Employee 1034: Employee Will Not Leave
# Employee 1035: Employee Will Not Leave
# Employee 1036: Employee Will Not Leave
# Employee 1037: Employee Will Not Leave
# Employee 1038: Employee Will Not Leave
# Employee 1039: Employee Will Not Leave
# Employee 1040: Employee Will Not Leave
# Employee 1041: Employee Will Not Leave
# Employee 1042: Employee Will Not Leave
# Employee 1043: Employee Will Not Leave
# Employee 1044: Employee Will Not Leave
# Employee 1045: Employee Will Not Leave
# Employee 1046: Employee Will Not Leave
# Employee 1047: Employee Will Not Leave
# Employee 1048: Employee Will Not Leave
# Employee 1049: Employee Will Not Leave
# Employee 1050: Employee Will Not Leave
# Employee 1051: Employee Will Not Leave
# Employee 1052: Employee Will Not Leave
# Employee 1053: Employee Will Not Leave
# Employee 1054: Employee Will Not Leave
# Employee 1055: Employee Will Not Leave
# Employee 1056: Employee Will Not Leave
# Employee 1057: Employee Will Not Leave
# Employee 1058: Employee Will Not Leave
# Employee 1059: Employee Will Not Leave
# Employee 1060: Employee Will Not Leave
# Employee 1061: Employee Will Not Leave
# Employee 1062: Employee Will Not Leave
# Employee 1063: Employee Will Not Leave
# Employee 1064: Employee Will Not Leave
# Employee 1065: Employee Will Not Leave
# Employee 1066: Employee Will Not Leave
# Employee 1067: Employee Will Not Leave
# Employee 1068: Employee Will Not Leave
# Employee 1069: Employee Will Not Leave
# Employee 1070: Employee Will Not Leave
# Employee 1071: Employee Will Not Leave
# Employee 1072: Employee Will Not Leave
# Employee 1073: Employee Will Not Leave
# Employee 1074: Employee Will Not Leave
# Employee 1075: Employee Will Not Leave
# Employee 1076: Employee Will Not Leave
# Employee 1077: Employee Will Not Leave
# Employee 1078: Employee Will Not Leave
# Employee 1079: Employee Will Not Leave
# Employee 1080: Employee Will Not Leave
# Employee 1081: Employee Will Not Leave
# Employee 1082: Employee Will Not Leave
# Employee 1083: Employee Will Not Leave
# Employee 1084: Employee Will Not Leave
# Employee 1085: Employee Will Not Leave
# Employee 1086: Employee Will Not Leave
# Employee 1087: Employee Will Not Leave
# Employee 1088: Employee Will Not Leave
# Employee 1089: Employee Will Not Leave
# Employee 1090: Employee Will Not Leave
# Employee 1091: Employee Will Not Leave
# Employee 1092: Employee Will Not Leave
# Employee 1093: Employee Will Not Leave
# Employee 1094: Employee Will Not Leave
# Employee 1095: Employee Will Not Leave
# Employee 1096: Employee Will Not Leave
# Employee 1097: Employee Will Not Leave
# Employee 1098: Employee Will Not Leave
# Employee 1099: Employee Will Not Leave
# Employee 1100: Employee Will Not Leave
# Employee 1101: Employee Will Not Leave
# Employee 1102: Employee Will Not Leave
# Employee 1103: Employee Will Not Leave
# Employee 1104: Employee Will Not Leave
# Employee 1105: Employee Will Not Leave
# Employee 1106: Employee Will Not Leave
# Employee 1107: Employee Will Not Leave
# Employee 1108: Employee Will Not Leave
# Employee 1109: Employee Will Not Leave
# Employee 1110: Employee Will Not Leave
# Employee 1111: Employee Will Not Leave
# Employee 1112: Employee Will Not Leave
# Employee 1113: Employee Will Not Leave
# Employee 1114: Employee Will Not Leave
# Employee 1115: Employee Will Not Leave
# Employee 1116: Employee Will Not Leave
# Employee 1117: Employee Will Not Leave
# Employee 1118: Employee Will Not Leave
# Employee 1119: Employee Will Not Leave
# Employee 1120: Employee Will Not Leave
# Employee 1121: Employee Will Not Leave
# Employee 1122: Employee Will Not Leave
# Employee 1123: Employee Will Not Leave
# Employee 1124: Employee Will Not Leave
# Employee 1125: Employee Will Not Leave
# Employee 1126: Employee Will Not Leave
# Employee 1127: Employee Will Not Leave
# Employee 1128: Employee Will Not Leave
# Employee 1129: Employee Will Not Leave
# Employee 1130: Employee Will Not Leave
# Employee 1131: Employee Will Not Leave
# Employee 1132: Employee Will Not Leave
# Employee 1133: Employee Will Not Leave
# Employee 1134: Employee Will Not Leave
# Employee 1135: Employee Will Not Leave
# Employee 1136: Employee Will Not Leave
# Employee 1137: Employee Will Not Leave
# Employee 1138: Employee Will Not Leave
# Employee 1139: Employee Will Not Leave
# Employee 1140: Employee Will Not Leave
# Employee 1141: Employee Will Not Leave
# Employee 1142: Employee Will Not Leave
# Employee 1143: Employee Will Not Leave
# Employee 1144: Employee Will Not Leave
# Employee 1145: Employee Will Not Leave
# Employee 1146: Employee Will Not Leave
# Employee 1147: Employee Will Not Leave
# Employee 1148: Employee Will Not Leave
# Employee 1149: Employee Will Not Leave
# Employee 1150: Employee Will Not Leave
# Employee 1151: Employee Will Not Leave
# Employee 1152: Employee Will Not Leave
# Employee 1153: Employee Will Not Leave
# Employee 1154: Employee Will Not Leave
# Employee 1155: Employee Will Not Leave
# Employee 1156: Employee Will Not Leave
# Employee 1157: Employee Will Not Leave
# Employee 1158: Employee Will Not Leave
# Employee 1159: Employee Will Not Leave
# Employee 1160: Employee Will Not Leave
# Employee 1161: Employee Will Not Leave
# Employee 1162: Employee Will Not Leave
# Employee 1163: Employee Will Not Leave
# Employee 1164: Employee Will Not Leave
# Employee 1165: Employee Will Not Leave
# Employee 1166: Employee Will Not Leave
# Employee 1167: Employee Will Not Leave
# Employee 1168: Employee Will Not Leave
# Employee 1169: Employee Will Not Leave
# Employee 1170: Employee Will Not Leave
# Employee 1171: Employee Will Not Leave
# Employee 1172: Employee Will Not Leave
# Employee 1173: Employee Will Not Leave
# Employee 1174: Employee Will Not Leave
# Employee 1175: Employee Will Not Leave
# Employee 1176: Employee Will Not Leave
# Employee 1177: Employee Will Not Leave
# Employee 1178: Employee Will Not Leave
# Employee 1179: Employee Will Not Leave
# Employee 1180: Employee Will Not Leave
# Employee 1181: Employee Will Not Leave
# Employee 1182: Employee Will Not Leave
# Employee 1183: Employee Will Not Leave
# Employee 1184: Employee Will Not Leave
# Employee 1185: Employee Will Not Leave
# Employee 1186: Employee Will Not Leave
# Employee 1187: Employee Will Not Leave
# Employee 1188: Employee Will Not Leave
# Employee 1189: Employee Will Not Leave
# Employee 1190: Employee Will Not Leave
# Employee 1191: Employee Will Not Leave
# Employee 1192: Employee Will Not Leave
# Employee 1193: Employee Will Not Leave
# Employee 1194: Employee Will Not Leave
# Employee 1195: Employee Will Not Leave
# Employee 1196: Employee Will Not Leave
# Employee 1197: Employee Will Not Leave
# Employee 1198: Employee Will Not Leave
# Employee 1199: Employee Will Not Leave
# Employee 1200: Employee Will Not Leave
# Employee 1201: Employee Will Not Leave
# Employee 1202: Employee Will Not Leave
# Employee 1203: Employee Will Not Leave
# Employee 1204: Employee Will Not Leave
# Employee 1205: Employee Will Not Leave
# Employee 1206: Employee Will Not Leave
# Employee 1207: Employee Will Not Leave
# Employee 1208: Employee Will Not Leave
# Employee 1209: Employee Will Not Leave
# Employee 1210: Employee Will Not Leave
# Employee 1211: Employee Will Not Leave
# Employee 1212: Employee Will Not Leave
# Employee 1213: Employee Will Not Leave
# Employee 1214: Employee Will Not Leave
# Employee 1215: Employee Will Not Leave
# Employee 1216: Employee Will Not Leave
# Employee 1217: Employee Will Not Leave
# Employee 1218: Employee Will Not Leave
# Employee 1219: Employee Will Not Leave
# Employee 1220: Employee Will Not Leave
# Employee 1221: Employee Will Not Leave
# Employee 1222: Employee Will Not Leave
# Employee 1223: Employee Will Not Leave
# Employee 1224: Employee Will Not Leave
# Employee 1225: Employee Will Not Leave
# Employee 1226: Employee Will Not Leave
# Employee 1227: Employee Will Not Leave
# Employee 1228: Employee Will Not Leave
# Employee 1229: Employee Will Not Leave
# Employee 1230: Employee Will Not Leave
# Employee 1231: Employee Will Not Leave
# Employee 1232: Employee Will Not Leave
# Employee 1233: Employee Will Not Leave
# Employee 1234: Employee Will Not Leave
# Employee 1235: Employee Will Not Leave
# Employee 1236: Employee Will Not Leave
# Employee 1237: Employee Will Not Leave
# Employee 1238: Employee Will Not Leave
# Employee 1239: Employee Will Not Leave
# Employee 1240: Employee Will Not Leave
# Employee 1241: Employee Will Not Leave
# Employee 1242: Employee Will Not Leave
# Employee 1243: Employee Will Not Leave
# Employee 1244: Employee Will Not Leave
# Employee 1245: Employee Will Not Leave
# Employee 1246: Employee Will Not Leave
# Employee 1247: Employee Will Not Leave
# Employee 1248: Employee Will Not Leave
# Employee 1249: Employee Will Not Leave
# Employee 1250: Employee Will Not Leave
# Employee 1251: Employee Will Not Leave
# Employee 1252: Employee Will Not Leave
# Employee 1253: Employee Will Not Leave
# Employee 1254: Employee Will Not Leave
# Employee 1255: Employee Will Not Leave
# Employee 1256: Employee Will Not Leave
# Employee 1257: Employee Will Not Leave
# Employee 1258: Employee Will Not Leave
# Employee 1259: Employee Will Not Leave
# Employee 1260: Employee Will Not Leave
# Employee 1261: Employee Will Not Leave
# Employee 1262: Employee Will Not Leave
# Employee 1263: Employee Will Not Leave
# Employee 1264: Employee Will Not Leave
# Employee 1265: Employee Will Not Leave
# Employee 1266: Employee Will Not Leave
# Employee 1267: Employee Will Not Leave
# Employee 1268: Employee Will Not Leave
# Employee 1269: Employee Will Not Leave
# Employee 1270: Employee Will Not Leave
# Employee 1271: Employee Will Not Leave
# Employee 1272: Employee Will Not Leave
# Employee 1273: Employee Will Not Leave
# Employee 1274: Employee Will Not Leave
# Employee 1275: Employee Will Not Leave
# Employee 1276: Employee Will Not Leave
# Employee 1277: Employee Will Not Leave
# Employee 1278: Employee Will Not Leave
# Employee 1279: Employee Will Not Leave
# Employee 1280: Employee Will Not Leave
# Employee 1281: Employee Will Not Leave
# Employee 1282: Employee Will Not Leave
# Employee 1283: Employee Will Not Leave
# Employee 1284: Employee Will Not Leave
# Employee 1285: Employee Will Not Leave
# Employee 1286: Employee Will Not Leave
# Employee 1287: Employee Will Not Leave
# Employee 1288: Employee Will Not Leave
# Employee 1289: Employee Will Not Leave
# Employee 1290: Employee Will Not Leave
# Employee 1291: Employee Will Not Leave
# Employee 1292: Employee Will Not Leave
# Employee 1293: Employee Will Not Leave
# Employee 1294: Employee Will Not Leave
# Employee 1295: Employee Will Not Leave
# Employee 1296: Employee Will Not Leave
# Employee 1297: Employee Will Not Leave
# Employee 1298: Employee Will Not Leave
# Employee 1299: Employee Will Not Leave
# Employee 1300: Employee Will Not Leave
# Employee 1301: Employee Will Not Leave
# Employee 1302: Employee Will Not Leave
# Employee 1303: Employee Will Not Leave
# Employee 1304: Employee Will Not Leave
# Employee 1305: Employee Will Not Leave
# Employee 1306: Employee Will Not Leave
# Employee 1307: Employee Will Not Leave
# Employee 1308: Employee Will Not Leave
# Employee 1309: Employee Will Not Leave
# Employee 1310: Employee Will Not Leave
# Employee 1311: Employee Will Not Leave
# Employee 1312: Employee Will Not Leave
# Employee 1313: Employee Will Not Leave
# Employee 1314: Employee Will Not Leave
# Employee 1315: Employee Will Not Leave
# Employee 1316: Employee Will Not Leave
# Employee 1317: Employee Will Not Leave
# Employee 1318: Employee Will Not Leave
# Employee 1319: Employee Will Not Leave
# Employee 1320: Employee Will Not Leave
# Employee 1321: Employee Will Not Leave
# Employee 1322: Employee Will Not Leave
# Employee 1323: Employee Will Not Leave
# Employee 1324: Employee Will Not Leave
# Employee 1325: Employee Will Not Leave
# Employee 1326: Employee Will Not Leave
# Employee 1327: Employee Will Not Leave
# Employee 1328: Employee Will Not Leave
# Employee 1329: Employee Will Not Leave
# Employee 1330: Employee Will Not Leave
# Employee 1331: Employee Will Not Leave
# Employee 1332: Employee Will Not Leave
# Employee 1333: Employee Will Not Leave
# Employee 1334: Employee Will Not Leave
# Employee 1335: Employee Will Not Leave
# Employee 1336: Employee Will Not Leave
# Employee 1337: Employee Will Not Leave
# Employee 1338: Employee Will Not Leave
# Employee 1339: Employee Will Not Leave
# Employee 1340: Employee Will Not Leave
# Employee 1341: Employee Will Not Leave
# Employee 1342: Employee Will Not Leave
# Employee 1343: Employee Will Not Leave
# Employee 1344: Employee Will Not Leave
# Employee 1345: Employee Will Not Leave
# Employee 1346: Employee Will Not Leave
# Employee 1347: Employee Will Not Leave
# Employee 1348: Employee Will Not Leave
# Employee 1349: Employee Will Not Leave
# Employee 1350: Employee Will Not Leave
# Employee 1351: Employee Will Not Leave
# Employee 1352: Employee Will Not Leave
# Employee 1353: Employee Will Not Leave
# Employee 1354: Employee Will Not Leave
# Employee 1355: Employee Will Not Leave
# Employee 1356: Employee Will Not Leave
# Employee 1357: Employee Will Not Leave
# Employee 1358: Employee Will Not Leave
# Employee 1359: Employee Will Not Leave
# Employee 1360: Employee Will Not Leave
# Employee 1361: Employee Will Not Leave
# Employee 1362: Employee Will Not Leave
# Employee 1363: Employee Will Not Leave
# Employee 1364: Employee Will Not Leave
# Employee 1365: Employee Will Not Leave
# Employee 1366: Employee Will Not Leave
# Employee 1367: Employee Will Not Leave
# Employee 1368: Employee Will Not Leave
# Employee 1369: Employee Will Not Leave
# Employee 1370: Employee Will Not Leave
# Employee 1371: Employee Will Not Leave
# Employee 1372: Employee Will Not Leave
# Employee 1373: Employee Will Not Leave
# Employee 1374: Employee Will Not Leave
# Employee 1375: Employee Will Not Leave
# Employee 1376: Employee Will Not Leave
# Employee 1377: Employee Will Not Leave
# Employee 1378: Employee Will Not Leave
# Employee 1379: Employee Will Not Leave
# Employee 1380: Employee Will Not Leave
# Employee 1381: Employee Will Not Leave
# Employee 1382: Employee Will Not Leave
# Employee 1383: Employee Will Not Leave
# Employee 1384: Employee Will Not Leave
# Employee 1385: Employee Will Not Leave
# Employee 1386: Employee Will Not Leave
# Employee 1387: Employee Will Not Leave
# Employee 1388: Employee Will Not Leave
# Employee 1389: Employee Will Not Leave
# Employee 1390: Employee Will Not Leave
# Employee 1391: Employee Will Not Leave
# Employee 1392: Employee Will Not Leave
# Employee 1393: Employee Will Not Leave
# Employee 1394: Employee Will Not Leave
# Employee 1395: Employee Will Not Leave
# Employee 1396: Employee Will Not Leave
# Employee 1397: Employee Will Not Leave
# Employee 1398: Employee Will Not Leave
# Employee 1399: Employee Will Not Leave
# Employee 1400: Employee Will Not Leave
# Employee 1401: Employee Will Not Leave
# Employee 1402: Employee Will Not Leave
# Employee 1403: Employee Will Not Leave
# Employee 1404: Employee Will Not Leave
# Employee 1405: Employee Will Not Leave
# Employee 1406: Employee Will Not Leave
# Employee 1407: Employee Will Not Leave
# Employee 1408: Employee Will Not Leave
# Employee 1409: Employee Will Not Leave
# Employee 1410: Employee Will Not Leave
# Employee 1411: Employee Will Not Leave
# Employee 1412: Employee Will Not Leave
# Employee 1413: Employee Will Not Leave
# Employee 1414: Employee Will Not Leave
# Employee 1415: Employee Will Not Leave
# Employee 1416: Employee Will Not Leave
# Employee 1417: Employee Will Not Leave
# Employee 1418: Employee Will Not Leave
# Employee 1419: Employee Will Not Leave
# Employee 1420: Employee Will Not Leave
# Employee 1421: Employee Will Not Leave
# Employee 1422: Employee Will Not Leave
# Employee 1423: Employee Will Not Leave
# Employee 1424: Employee Will Not Leave
# Employee 1425: Employee Will Not Leave
# Employee 1426: Employee Will Not Leave
# Employee 1427: Employee Will Not Leave
# Employee 1428: Employee Will Not Leave
# Employee 1429: Employee Will Not Leave
# Employee 1430: Employee Will Not Leave
# Employee 1431: Employee Will Not Leave
# Employee 1432: Employee Will Not Leave
# Employee 1433: Employee Will Not Leave
# Employee 1434: Employee Will Not Leave
# Employee 1435: Employee Will Not Leave
# Employee 1436: Employee Will Not Leave
# Employee 1437: Employee Will Not Leave
# Employee 1438: Employee Will Not Leave
# Employee 1439: Employee Will Not Leave
# Employee 1440: Employee Will Not Leave
# Employee 1441: Employee Will Not Leave
# Employee 1442: Employee Will Not Leave
# Employee 1443: Employee Will Not Leave
# Employee 1444: Employee Will Not Leave
# Employee 1445: Employee Will Not Leave
# Employee 1446: Employee Will Not Leave
# Employee 1447: Employee Will Not Leave
# Employee 1448: Employee Will Not Leave
# Employee 1449: Employee Will Not Leave
# Employee 1450: Employee Will Not Leave
# Employee 1451: Employee Will Not Leave
# Employee 1452: Employee Will Not Leave
# Employee 1453: Employee Will Not Leave
# Employee 1454: Employee Will Not Leave
# Employee 1455: Employee Will Not Leave
# Employee 1456: Employee Will Not Leave
# Employee 1457: Employee Will Not Leave
# Employee 1458: Employee Will Not Leave
# Employee 1459: Employee Will Not Leave
# Employee 1460: Employee Will Not Leave
# Employee 1461: Employee Will Not Leave
# Employee 1462: Employee Will Not Leave
# Employee 1463: Employee Will Not Leave
# Employee 1464: Employee Will Not Leave
# Employee 1465: Employee Will Not Leave
# Employee 1466: Employee Will Not Leave
# Employee 1467: Employee Will Not Leave
# Employee 1468: Employee Will Not Leave
# Employee 1469: Employee Will Not Leave
# Employee 1470: Employee Will Not Leave
